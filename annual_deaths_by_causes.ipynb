# %% [markdown]
# # Importation

# %%
#importation des packages

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
#importation du jeu de données
data = pd.read_csv("annual_deaths_by_causes.csv", delimiter = ",")
df = data.copy()
pd.set_option('display.max_column', 100)
pd.set_option('display.max_row', 100)

# %% [markdown]
# # Analyse exploratoire

# %%
df.shape
# Out:
# (7273, 35)

# %%
df.head(5)
# Out:
#        country code                                               year  \
# 0  Afghanistan  AFG  0       2007\n1       2008\n2       2009\n3   ...
# 1  Afghanistan  AFG  0       2007\n1       2008\n2       2009\n3   ...
# 2  Afghanistan  AFG  0       2007\n1       2008\n2       2009\n3   ...
# 3  Afghanistan  AFG  0       2007\n1       2008\n2       2009\n3   ...
# 4  Afghanistan  AFG  0       2007\n1       2008\n2       2009\n3   ...
#
#    meningitis  alzheimer's_diesease  parkinson's_disease  \
# 0      2933.0                1402.0                450.0
# 1      2731.0                1424.0                455.0
# 2      2460.0                1449.0                460.0
# 3      2327.0                1508.0                473.0
# 4      2254.0                1544.0                482.0
#
#    nutritional_deficiency  malaria  drowning  interpersonal_violence  \
# 0                  2488.0    393.0    2127.0                  3657.0
# ...

# %%
df.info()
#Je remarque ici que la colonne "year" est considérée comme une colonne de nombres entiers (int64), je vais alors mettre à jour le format de la colonne au format texte.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7273 entries, 0 to 7272
# Data columns (total 35 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   country                               7273 non-null   object
#  1   code                                  6206 non-null   object
#  2   year                                  7273 non-null   int64
#  3   meningitis                            6840 non-null   float64
#  4   alzheimer's_diesease                  6840 non-null   float64
#  5   parkinson's_disease                   6840 non-null   float64
#  6   nutritional_deficiency                6840 non-null   float64
#  7   malaria                               6840 non-null   float64
#  8   drowning                              6840 non-null   float64
#  9   interpersonal_violence                6840 non-null   float64
# ...

# %%
df["year"] = str(df["year"])
df.dtypes.value_counts().plot.pie(title="Répartition des formats des colonnes", label='')
#on peut constater qu'il n'y a plus de colonne au format de nombres entiers. Et que la colonne "year" est maintenant considérée comme un objet.
# Out:
# <AxesSubplot:title={'center':'Répartition des formats des colonnes'}>

# %% [markdown]
# ## Contexte statistique
# - Population : 7273 ensembles de décès annuels
# - Nature des variables : 33 variables quantitatives discrètes  et 3 variables qualitatives nominales

# %%
#indicateurs statistiques de base
df.describe()
# Out:
#           meningitis  alzheimer's_diesease  parkinson's_disease  \
# count    6840.000000          6.840000e+03          6840.000000
# mean     8213.149561          2.736319e+04          6493.627339
# std     34982.933895          1.113146e+05         25767.447063
# min         0.000000          0.000000e+00             0.000000
# 25%        19.000000          1.287500e+02            37.000000
# 50%       150.500000          8.455000e+02           209.000000
# 75%      1622.250000          4.251000e+03           984.000000
# max    432524.000000          1.623276e+06        362907.000000
#
#        nutritional_deficiency        malaria       drowning  \
# count             6840.000000    6840.000000    6840.000000
# mean             11006.353947   18903.160234    8619.055117
# std              48289.687100   97346.780570   35879.406010
# min                  0.000000       0.000000       0.000000
# 25%                 11.000000       0.000000      39.000000
# ...

# %% [markdown]
# ### Valeurs manquantes
#
# - La colonne qui comporte le plus de valeurs manquantes est "terrorism"
# On peut donc supposer qu'il y a peu de décès dû au terrorisme par rapport aux autres causes.

# %%
#graphique qui permet de voir en coup d'oeil les colonnes pour lesquelles il y a des beaucoup de valeurs manquantes.
plt.figure(figsize=(12, 7))
sns.heatmap(df.isna(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
(df.isna().sum()/df.shape[0]).sort_values(ascending=True)
# Out:
# country                                 0.000000
# year                                    0.000000
# exposure_to_forces_of_nature            0.059535
# diarrheal_diseases                      0.059535
# environmental_heat_and_cold_exposure    0.059535
# neoplasms                               0.059535
# conflict_and_terrorism                  0.059535
# diabetes_mellitus                       0.059535
# chronic_kidney_disease                  0.059535
# poisonings                              0.059535
# protein_energy_malnutrition             0.059535
# road_injuries                           0.059535
# chronic_respiratory_diseases            0.059535
# chronic_liver_diseases                  0.059535
# digestive_diseases                      0.059535
# self_harm                               0.059535
# fire_heat_hot_substance                 0.059535
# alcohol_use_disorders                   0.059535
# lower_respiratory_infections            0.059535
# ...

# %% [markdown]
# ### Exploration des variables quantitatives

# %%
for col in df.select_dtypes('float'):
    plt.figure()
    sns.histplot(df[col], bins = 10)
# Out:
# C:\Users\iroxx\AppData\Local\Temp\ipykernel_11852\957740393.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
