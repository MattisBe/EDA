# %% [markdown]
# # Importation

# %%
#importation des packages

import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import random

# %%
#importation du jeu de données
data = pd.read_csv("annual_deaths_by_causes.csv", delimiter = ",")
df = data.copy()

# %% [markdown]
# # Analyse exploratoire

# %%
df.shape
# Out:
# (7273, 35)

# %%
df.head(100)
# Out:
#         country code  year  meningitis  alzheimer's_diesease  \
# 0   Afghanistan  AFG  2007      2933.0                1402.0
# 1   Afghanistan  AFG  2008      2731.0                1424.0
# 2   Afghanistan  AFG  2009      2460.0                1449.0
# 3   Afghanistan  AFG  2011      2327.0                1508.0
# 4   Afghanistan  AFG  2012      2254.0                1544.0
# ..          ...  ...   ...         ...                   ...
# 95      Algeria  DZA  1995       678.0                1763.0
# 96      Algeria  DZA  1996       650.0                1855.0
# 97      Algeria  DZA  1997       637.0                1945.0
# 98      Algeria  DZA  1998       622.0                2037.0
# 99      Algeria  DZA  1999       602.0                2129.0
#
#     parkinson's_disease  nutritional_deficiency  malaria  drowning  \
# 0                 450.0                  2488.0    393.0    2127.0
# 1                 455.0                  2277.0    255.0    1973.0
# ...

# %%
df.dtypes.value_counts()
# Out:
# float64    32
# object      2
# int64       1
# dtype: int64

# %% [markdown]
# # Contexte statistique
# - Population : 7273 ensembles de décès annuels
# - Nature des variables : 33 variables quantitatives discrètes  et 2 variables qualitatives nominales
